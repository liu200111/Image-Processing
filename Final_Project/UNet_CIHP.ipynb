# %%
import keras
from keras import layers
from keras import ops

import os
import numpy as np
from glob import glob
import cv2
from scipy.io import loadmat
import matplotlib.pyplot as plt

# For data preprocessing
from tensorflow import image as tf_image
from tensorflow import data as tf_data
from tensorflow import io as tf_io

# %%
# !gdown "1B9A9UCJYMwTL4oBEo4RZfbMZMaZhKJaz&confirm=t"
# !unzip -q instance-level-human-parsing.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1B9A9UCJYMwTL4oBEo4RZfbMZMaZhKJaz&confirm=t
# To: /content/instance-level-human-parsing.zip
# 100% 2.91G/2.91G [00:33<00:00, 86.9MB/s]

# %%
IMAGE_SIZE = 512
BATCH_SIZE = 16
NUM_CLASSES = 20
DATA_DIR = "./instance-level_human_parsing/instance-level_human_parsing/Training"
NUM_TRAIN_IMAGES = 1000
NUM_VAL_IMAGES = 50

train_images = sorted(glob(os.path.join(DATA_DIR, "Images/*")))[:NUM_TRAIN_IMAGES]
train_masks = sorted(glob(os.path.join(DATA_DIR, "Category_ids/*")))[:NUM_TRAIN_IMAGES]
val_images = sorted(glob(os.path.join(DATA_DIR, "Images/*")))[
    NUM_TRAIN_IMAGES : NUM_VAL_IMAGES + NUM_TRAIN_IMAGES
]
val_masks = sorted(glob(os.path.join(DATA_DIR, "Category_ids/*")))[
    NUM_TRAIN_IMAGES : NUM_VAL_IMAGES + NUM_TRAIN_IMAGES
]


def read_image(image_path, mask=False):
    image = tf_io.read_file(image_path)
    if mask:
        image = tf_image.decode_png(image, channels=1)
        image.set_shape([None, None, 1])
        image = tf_image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
    else:
        image = tf_image.decode_png(image, channels=3)
        image.set_shape([None, None, 3])
        image = tf_image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
    return image


def load_data(image_list, mask_list):
    image = read_image(image_list)
    mask = read_image(mask_list, mask=True)
    return image, mask


def data_generator(image_list, mask_list):
    dataset = tf_data.Dataset.from_tensor_slices((image_list, mask_list))
    dataset = dataset.map(load_data, num_parallel_calls=tf_data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset


train_dataset = data_generator(train_images, train_masks)
val_dataset = data_generator(val_images, val_masks)

print("Train Dataset:", train_dataset)
print("Val Dataset:", val_dataset)
# Out:
# Train Dataset: <_BatchDataset element_spec=(TensorSpec(shape=(16, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(16, 512, 512, 1), dtype=tf.float32, name=None))>
# Val Dataset: <_BatchDataset element_spec=(TensorSpec(shape=(16, 512, 512, 3), dtype=tf.float32, name=None), TensorSpec(shape=(16, 512, 512, 1), dtype=tf.float32, name=None))>

# %%
## Step 3: Define UNet Model

def get_model(img_size, num_classes):
    inputs = keras.Input(shape=(img_size, img_size, 3))

    ### [First half of the network: downsampling inputs] ###

    # Entry block
    x = layers.Conv2D(32, 3, strides=2, padding="same")(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)

    previous_block_activation = x  # Set aside residual

    # Blocks 1, 2, 3 are identical apart from the feature depth.
    for filters in [64, 128, 256]:
        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.SeparableConv2D(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D(3, strides=2, padding="same")(x)

        # Project residual
        residual = layers.Conv2D(filters, 1, strides=2, padding="same")(
            previous_block_activation
        )
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    ### [Second half of the network: upsampling inputs] ###

    for filters in [256, 128, 64, 32]:
        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation("relu")(x)
        x = layers.Conv2DTranspose(filters, 3, padding="same")(x)
        x = layers.BatchNormalization()(x)

        x = layers.UpSampling2D(2)(x)

        # Project residual
        residual = layers.UpSampling2D(2)(previous_block_activation)
        residual = layers.Conv2D(filters, 1, padding="same")(residual)
        x = layers.add([x, residual])  # Add back residual
        previous_block_activation = x  # Set aside next residual

    # Add a per-pixel classification layer
    outputs = layers.Conv2D(num_classes, 3, activation="softmax", padding="same")(x)

    # Define the model
    model = keras.Model(inputs, outputs)
    return model


# Free up RAM in case the model definition cells were run multiple times
keras.backend.clear_session()

# Build model
model = get_model(IMAGE_SIZE, NUM_CLASSES)

model.summary()  # Print model summary to check the architecture
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)  │ (None, 512, 512, 3)    │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d (Conv2D)           │ (None, 256, 256, 32)   │            896 │ input_layer[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization       │ (None, 256, 256, 32)   │            128 │ conv2d[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation (Activation)   │ (None, 256, 256, 32)   │              0 │ batch_normalization[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_1 (Activation) │ (None, 256, 256, 32)   │              0 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d          │ (None, 256, 256, 64)   │          2,400 │ activation_1[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 256, 256, 64)   │            256 │ separable_conv2d[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_2 (Activation) │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_1        │ (None, 256, 256, 64)   │          4,736 │ activation_2[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_2     │ (None, 256, 256, 64)   │            256 │ separable_conv2d_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d             │ (None, 128, 128, 64)   │              0 │ batch_normalization_2… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_1 (Conv2D)         │ (None, 128, 128, 64)   │          2,112 │ activation[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 128, 128, 64)   │              0 │ max_pooling2d[0][0],   │
# │                           │                        │                │ conv2d_1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_3 (Activation) │ (None, 128, 128, 64)   │              0 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_2        │ (None, 128, 128, 128)  │          8,896 │ activation_3[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_3     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_4 (Activation) │ (None, 128, 128, 128)  │              0 │ batch_normalization_3… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_3        │ (None, 128, 128, 128)  │         17,664 │ activation_4[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 128, 128, 128)  │            512 │ separable_conv2d_3[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_1           │ (None, 64, 64, 128)    │              0 │ batch_normalization_4… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_2 (Conv2D)         │ (None, 64, 64, 128)    │          8,320 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_1 (Add)               │ (None, 64, 64, 128)    │              0 │ max_pooling2d_1[0][0], │
# │                           │                        │                │ conv2d_2[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_5 (Activation) │ (None, 64, 64, 128)    │              0 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_4        │ (None, 64, 64, 256)    │         34,176 │ activation_5[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_6 (Activation) │ (None, 64, 64, 256)    │              0 │ batch_normalization_5… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ separable_conv2d_5        │ (None, 64, 64, 256)    │         68,096 │ activation_6[0][0]     │
# │ (SeparableConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_6     │ (None, 64, 64, 256)    │          1,024 │ separable_conv2d_5[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_2           │ (None, 32, 32, 256)    │              0 │ batch_normalization_6… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_3 (Conv2D)         │ (None, 32, 32, 256)    │         33,024 │ add_1[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_2 (Add)               │ (None, 32, 32, 256)    │              0 │ max_pooling2d_2[0][0], │
# │                           │                        │                │ conv2d_3[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_7 (Activation) │ (None, 32, 32, 256)    │              0 │ add_2[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose          │ (None, 32, 32, 256)    │        590,080 │ activation_7[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_7     │ (None, 32, 32, 256)    │          1,024 │ conv2d_transpose[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_8 (Activation) │ (None, 32, 32, 256)    │              0 │ batch_normalization_7… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_1        │ (None, 32, 32, 256)    │        590,080 │ activation_8[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_8     │ (None, 32, 32, 256)    │          1,024 │ conv2d_transpose_1[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_1           │ (None, 64, 64, 256)    │              0 │ add_2[0][0]            │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d             │ (None, 64, 64, 256)    │              0 │ batch_normalization_8… │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_4 (Conv2D)         │ (None, 64, 64, 256)    │         65,792 │ up_sampling2d_1[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_3 (Add)               │ (None, 64, 64, 256)    │              0 │ up_sampling2d[0][0],   │
# │                           │                        │                │ conv2d_4[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_9 (Activation) │ (None, 64, 64, 256)    │              0 │ add_3[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_2        │ (None, 64, 64, 128)    │        295,040 │ activation_9[0][0]     │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_9     │ (None, 64, 64, 128)    │            512 │ conv2d_transpose_2[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_10             │ (None, 64, 64, 128)    │              0 │ batch_normalization_9… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_3        │ (None, 64, 64, 128)    │        147,584 │ activation_10[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_10    │ (None, 64, 64, 128)    │            512 │ conv2d_transpose_3[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_3           │ (None, 128, 128, 256)  │              0 │ add_3[0][0]            │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_2           │ (None, 128, 128, 128)  │              0 │ batch_normalization_1… │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 128, 128, 128)  │         32,896 │ up_sampling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_4 (Add)               │ (None, 128, 128, 128)  │              0 │ up_sampling2d_2[0][0], │
# │                           │                        │                │ conv2d_5[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_11             │ (None, 128, 128, 128)  │              0 │ add_4[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_4        │ (None, 128, 128, 64)   │         73,792 │ activation_11[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_11    │ (None, 128, 128, 64)   │            256 │ conv2d_transpose_4[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_12             │ (None, 128, 128, 64)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_5        │ (None, 128, 128, 64)   │         36,928 │ activation_12[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_12    │ (None, 128, 128, 64)   │            256 │ conv2d_transpose_5[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_5           │ (None, 256, 256, 128)  │              0 │ add_4[0][0]            │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_4           │ (None, 256, 256, 64)   │              0 │ batch_normalization_1… │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 256, 256, 64)   │          8,256 │ up_sampling2d_5[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_5 (Add)               │ (None, 256, 256, 64)   │              0 │ up_sampling2d_4[0][0], │
# │                           │                        │                │ conv2d_6[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_13             │ (None, 256, 256, 64)   │              0 │ add_5[0][0]            │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_6        │ (None, 256, 256, 32)   │         18,464 │ activation_13[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_13    │ (None, 256, 256, 32)   │            128 │ conv2d_transpose_6[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ activation_14             │ (None, 256, 256, 32)   │              0 │ batch_normalization_1… │
# │ (Activation)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_transpose_7        │ (None, 256, 256, 32)   │          9,248 │ activation_14[0][0]    │
# │ (Conv2DTranspose)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_14    │ (None, 256, 256, 32)   │            128 │ conv2d_transpose_7[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_7           │ (None, 512, 512, 64)   │              0 │ add_5[0][0]            │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ up_sampling2d_6           │ (None, 512, 512, 32)   │              0 │ batch_normalization_1… │
# │ (UpSampling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_7 (Conv2D)         │ (None, 512, 512, 32)   │          2,080 │ up_sampling2d_7[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add_6 (Add)               │ (None, 512, 512, 32)   │              0 │ up_sampling2d_6[0][0], │
# │                           │                        │                │ conv2d_7[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_8 (Conv2D)         │ (None, 512, 512, 20)   │          5,780 │ add_6[0][0]            │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,063,892 (7.87 MB)
#  Trainable params: 2,060,116 (7.86 MB)
#  Non-trainable params: 3,776 (14.75 KB)

# %%
loss = keras.losses.SparseCategoricalCrossentropy(from_logits=True)
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.001),
    loss=loss,
    metrics=["accuracy"],
)

history = model.fit(train_dataset, validation_data=val_dataset, epochs=50)

plt.plot(history.history["loss"])
plt.title("Training Loss")
plt.ylabel("loss")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["accuracy"])
plt.title("Training Accuracy")
plt.ylabel("accuracy")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["val_loss"])
plt.title("Validation Loss")
plt.ylabel("val_loss")
plt.xlabel("epoch")
plt.show()

plt.plot(history.history["val_accuracy"])
plt.title("Validation Accuracy")
plt.ylabel("val_accuracy")
plt.xlabel("epoch")
plt.show()
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/src/backend/tensorflow/nn.py:635: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 110s 596ms/step - accuracy: 0.4751 - loss: 3.6496 - val_accuracy: 0.5655 - val_loss: 1.7894
# Epoch 2/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 76s 548ms/step - accuracy: 0.5823 - loss: 1.4428 - val_accuracy: 0.5960 - val_loss: 2.3240
# Epoch 3/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 42s 567ms/step - accuracy: 0.5928 - loss: 1.3669 - val_accuracy: 0.5960 - val_loss: 2.8517
# Epoch 4/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 562ms/step - accuracy: 0.6001 - loss: 1.3232 - val_accuracy: 0.5960 - val_loss: 3.1073
# Epoch 5/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 565ms/step - accuracy: 0.6073 - loss: 1.2870 - val_accuracy: 0.5960 - val_loss: 3.0993
# Epoch 6/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 569ms/step - accuracy: 0.6152 - loss: 1.2541 - val_accuracy: 0.5960 - val_loss: 2.8261
# Epoch 7/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 572ms/step - accuracy: 0.6231 - loss: 1.2205 - val_accuracy: 0.5960 - val_loss: 2.6045
# Epoch 8/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 574ms/step - accuracy: 0.6306 - loss: 1.1929 - val_accuracy: 0.5960 - val_loss: 2.2020
# Epoch 9/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 576ms/step - accuracy: 0.6378 - loss: 1.1669 - val_accuracy: 0.5974 - val_loss: 1.7566
# Epoch 10/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 576ms/step - accuracy: 0.6451 - loss: 1.1390 - val_accuracy: 0.6023 - val_loss: 1.5820
# Epoch 11/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 577ms/step - accuracy: 0.6519 - loss: 1.1138 - val_accuracy: 0.6087 - val_loss: 1.4599
# Epoch 12/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 577ms/step - accuracy: 0.6576 - loss: 1.0905 - val_accuracy: 0.6129 - val_loss: 1.4638
# Epoch 13/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 577ms/step - accuracy: 0.6640 - loss: 1.0670 - val_accuracy: 0.6161 - val_loss: 1.5276
# Epoch 14/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 42s 587ms/step - accuracy: 0.6705 - loss: 1.0438 - val_accuracy: 0.6296 - val_loss: 1.4199
# Epoch 15/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 40s 579ms/step - accuracy: 0.6769 - loss: 1.0229 - val_accuracy: 0.6388 - val_loss: 1.4138
# Epoch 16/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 582ms/step - accuracy: 0.6817 - loss: 1.0064 - val_accuracy: 0.6360 - val_loss: 1.5108
# Epoch 17/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 36s 587ms/step - accuracy: 0.6888 - loss: 0.9820 - val_accuracy: 0.6543 - val_loss: 1.1993
# Epoch 18/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 37s 589ms/step - accuracy: 0.6939 - loss: 0.9701 - val_accuracy: 0.6444 - val_loss: 1.2398
# Epoch 19/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 583ms/step - accuracy: 0.6994 - loss: 0.9470 - val_accuracy: 0.6510 - val_loss: 1.1713
# Epoch 20/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 581ms/step - accuracy: 0.7066 - loss: 0.9224 - val_accuracy: 0.6728 - val_loss: 1.1485
# Epoch 21/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 583ms/step - accuracy: 0.7091 - loss: 0.9160 - val_accuracy: 0.6701 - val_loss: 1.1607
# Epoch 22/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 581ms/step - accuracy: 0.7139 - loss: 0.8998 - val_accuracy: 0.6694 - val_loss: 1.1225
# Epoch 23/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 580ms/step - accuracy: 0.7170 - loss: 0.8866 - val_accuracy: 0.6645 - val_loss: 1.2382
# Epoch 24/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 580ms/step - accuracy: 0.7275 - loss: 0.8606 - val_accuracy: 0.6733 - val_loss: 1.2475
# Epoch 25/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 580ms/step - accuracy: 0.7359 - loss: 0.8317 - val_accuracy: 0.6716 - val_loss: 1.3093
# Epoch 26/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 581ms/step - accuracy: 0.7407 - loss: 0.8103 - val_accuracy: 0.6760 - val_loss: 1.3688
# Epoch 27/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 581ms/step - accuracy: 0.7474 - loss: 0.7907 - val_accuracy: 0.6731 - val_loss: 1.3240
# Epoch 28/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 580ms/step - accuracy: 0.7503 - loss: 0.7850 - val_accuracy: 0.6504 - val_loss: 1.2504
# Epoch 29/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 581ms/step - accuracy: 0.7575 - loss: 0.7667 - val_accuracy: 0.6082 - val_loss: 1.3478
# Epoch 30/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 580ms/step - accuracy: 0.7638 - loss: 0.7456 - val_accuracy: 0.6086 - val_loss: 1.4106
# Epoch 31/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 578ms/step - accuracy: 0.7761 - loss: 0.7100 - val_accuracy: 0.5819 - val_loss: 1.5777
# Epoch 32/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 36s 584ms/step - accuracy: 0.7881 - loss: 0.6736 - val_accuracy: 0.6009 - val_loss: 1.5672
# Epoch 33/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 582ms/step - accuracy: 0.7890 - loss: 0.6677 - val_accuracy: 0.6312 - val_loss: 1.3226
# Epoch 34/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 37s 589ms/step - accuracy: 0.7900 - loss: 0.6668 - val_accuracy: 0.6495 - val_loss: 1.4375
# Epoch 35/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 586ms/step - accuracy: 0.7925 - loss: 0.6570 - val_accuracy: 0.6632 - val_loss: 1.3960
# Epoch 36/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 582ms/step - accuracy: 0.8015 - loss: 0.6350 - val_accuracy: 0.6591 - val_loss: 1.5367
# Epoch 37/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 582ms/step - accuracy: 0.7979 - loss: 0.6434 - val_accuracy: 0.6568 - val_loss: 1.4991
# Epoch 38/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 580ms/step - accuracy: 0.8079 - loss: 0.6144 - val_accuracy: 0.6347 - val_loss: 1.4374
# Epoch 39/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 581ms/step - accuracy: 0.8193 - loss: 0.5832 - val_accuracy: 0.6520 - val_loss: 1.5078
# Epoch 40/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 36s 586ms/step - accuracy: 0.8223 - loss: 0.5732 - val_accuracy: 0.6469 - val_loss: 1.4507
# Epoch 41/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 581ms/step - accuracy: 0.8249 - loss: 0.5650 - val_accuracy: 0.6681 - val_loss: 1.3304
# Epoch 42/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 36s 587ms/step - accuracy: 0.8269 - loss: 0.5581 - val_accuracy: 0.6439 - val_loss: 1.8443
# Epoch 43/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 593ms/step - accuracy: 0.8311 - loss: 0.5456 - val_accuracy: 0.6512 - val_loss: 1.6080
# Epoch 44/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 586ms/step - accuracy: 0.8307 - loss: 0.5489 - val_accuracy: 0.6587 - val_loss: 1.8432
# Epoch 45/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 584ms/step - accuracy: 0.8385 - loss: 0.5229 - val_accuracy: 0.6698 - val_loss: 1.4905
# Epoch 46/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 583ms/step - accuracy: 0.8411 - loss: 0.5148 - val_accuracy: 0.6709 - val_loss: 1.4854
# Epoch 47/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 37s 590ms/step - accuracy: 0.8440 - loss: 0.5086 - val_accuracy: 0.6632 - val_loss: 1.5247
# Epoch 48/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 41s 589ms/step - accuracy: 0.8503 - loss: 0.4856 - val_accuracy: 0.6499 - val_loss: 1.5585
# Epoch 49/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 36s 587ms/step - accuracy: 0.8596 - loss: 0.4617 - val_accuracy: 0.6684 - val_loss: 1.4168
# Epoch 50/50
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 42s 598ms/step - accuracy: 0.8616 - loss: 0.4562 - val_accuracy: 0.6455 - val_loss: 1.8725

# %%
model.save('unet_model_v1.keras')

# %%
# Loading the Colormap
colormap = loadmat(
    "./instance-level_human_parsing/instance-level_human_parsing/human_colormap.mat"
)["colormap"]
colormap = colormap * 100
colormap = colormap.astype(np.uint8)

def infer(model, image_tensor):
    predictions = model.predict(np.expand_dims((image_tensor), axis=0))
    predictions = np.squeeze(predictions)
    predictions = np.argmax(predictions, axis=2)
    return predictions

def decode_segmentation_masks(mask, colormap, n_classes):
    r = np.zeros_like(mask).astype(np.uint8)
    g = np.zeros_like(mask).astype(np.uint8)
    b = np.zeros_like(mask).astype(np.uint8)
    for l in range(0, n_classes):
        idx = mask == l
        r[idx] = colormap[l, 0]
        g[idx] = colormap[l, 1]
        b[idx] = colormap[l, 2]
    rgb = np.stack([r, g, b], axis=2)
    return rgb

def get_overlay(image, colored_mask):
    image = keras.utils.array_to_img(image)
    image = np.array(image).astype(np.uint8)
    overlay = cv2.addWeighted(image, 0.35, colored_mask, 0.65, 0)
    return overlay

def plot_samples_matplotlib(display_list, figsize=(5, 3)):
    _, axes = plt.subplots(nrows=1, ncols=len(display_list), figsize=figsize)
    for i in range(len(display_list)):
        if display_list[i].shape[-1] == 3:
            axes[i].imshow(keras.utils.array_to_img(display_list[i]))
        else:
            axes[i].imshow(display_list[i])
    plt.show()

def plot_predictions(images_list, colormap, model):
    for image_file in images_list:
        image_tensor = read_image(image_file)
        prediction_mask = infer(image_tensor=image_tensor, model=model)
        prediction_colormap = decode_segmentation_masks(prediction_mask, colormap, 20)
        overlay = get_overlay(image_tensor, prediction_colormap)
        plot_samples_matplotlib(
            [image_tensor, overlay, prediction_colormap], figsize=(18, 14)
        )

# %%
plot_predictions(train_images[:4], colormap, model=model)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
plot_predictions(val_images[:4], colormap, model=model)
